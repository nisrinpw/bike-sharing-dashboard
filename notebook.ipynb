# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:** Nisrina Prima Wiguna
# - **Email:** CDCC200D6X2289@student.devacademy.id
# - **ID Dicoding:** CDCC200D6X2289

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Bagaimana pengaruh kondisi cuaca (weathersit) terhadap jumlah total penyewaan sepeda (cnt) pada tahun 2011–2012, dan kondisi cuaca mana yang menyebabkan penurunan penyewaan paling signifikan?
# - **Pertanyaan 2:** Pada musim apa (season) jumlah penyewaan sepeda tertinggi dan terendah terjadi selama tahun 2011–2012, serta bagaimana strategi operasional yang dapat diterapkan berdasarkan pola musiman tersebut?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
pip install streamlit

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load DataFrame

# %%
day_df = pd.read_csv("day.csv")
hour_df = pd.read_csv("hour.csv")

day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# **Insight:** (Opsional)
# - Dataset yang digunakan adalah Bike Sharing Dataset yang terdiri dari dua file utama, yaitu day.csv dan hour.csv.
# - File day.csv berisi data penyewaan sepeda harian, sedangkan hour.csv berisi data penyewaan sepeda per jam.
# - Untuk analisis utama digunakan day.csv karena lebih sesuai untuk melihat pola penyewaan berdasarkan musim dan kondisi cuaca.

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Identifying Data Problems

# %%
# informasi umum dataset
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
# cek missing value
print("Missing Value:")
print(day_df.isna().sum())
# Out:
# Missing Value:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# cek duplicate data
print("\nJumlah Duplicate Data:")
print(day_df.duplicated().sum())
# Out:
# Jumlah Duplicate Data:
# 0

# %%
# ringkasan statistik deskriptif
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
# cek invalid value pada variabel kategorik
print("\nUnique Values:")
print("Season:", day_df["season"].unique())
print("Weather Situation:", day_df["weathersit"].unique())
print("Working Day:", day_df["workingday"].unique())
print("Holiday:", day_df["holiday"].unique())
# Out:
# Unique Values:
# Season: [1 2 3 4]
# Weather Situation: [2 1 3]
# Working Day: [0 1]
# Holiday: [0 1]

# %%
# cek kemungkinan inaccurate value
# misalnya nilai minimum dan maksimum variabel numerik

print("\nMinimum Value:")
print(day_df[["cnt", "temp", "hum", "windspeed"]].min())

print("\nMaximum Value:")
print(day_df[["cnt", "temp", "hum", "windspeed"]].max())
# Out:
# Minimum Value:
# cnt          22.000000
# temp          0.059130
# hum           0.000000
# windspeed     0.022392
# dtype: float64
#
# Maximum Value:
# cnt          8714.000000
# temp            0.861667
# hum             0.972500
# windspeed       0.507463
# dtype: float64

# %%
# cek outlier menggunakan boxplot

plt.figure(figsize=(12,8))

plt.subplot(2,2,1)
sns.boxplot(x=day_df["cnt"])
plt.title("Total Bike Rentals (cnt)")

plt.subplot(2,2,2)
sns.boxplot(x=day_df["temp"])
plt.title("Temperature (temp)")

plt.subplot(2,2,3)
sns.boxplot(x=day_df["hum"])
plt.title("Humidity (hum)")

plt.subplot(2,2,4)
sns.boxplot(x=day_df["windspeed"])
plt.title("Windspeed")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Steps to Take:**
# - Mengubah tipe data kolom dteday dari object menjadi datetime.
# - Memastikan seluruh variabel kategorik memiliki nilai yang valid sesuai dokumentasi dataset.
# - Memverifikasi bahwa tidak terdapat missing value maupun duplicate data.
# - Mengevaluasi outlier pada variabel hum dan windspeed untuk menentukan apakah perlu dipertahankan atau ditangani lebih lanjut.
# - Melakukan verifikasi akhir agar dataset siap digunakan pada tahap Exploratory Data Analysis (EDA).

# %% [markdown]
# **Insight:** (Opsional)
# - Dataset memiliki kualitas yang cukup baik karena tidak ditemukan missing value maupun duplicate data.
# - Permasalahan utama terdapat pada kolom dteday yang masih bertipe object, sehingga perlu dikonversi menjadi format datetime.
# - Variabel kategorik seperti season, weathersit, workingday, dan holiday telah divalidasi dan menunjukkan nilai yang konsisten dengan dokumentasi dataset.
# - Hasil pemeriksaan outlier menunjukkan terdapat beberapa nilai ekstrem pada variabel hum (humidity) dan windspeed, sehingga perlu dievaluasi apakah merupakan kondisi nyata atau kesalahan pencatatan.
# - Variabel cnt dan temp tidak menunjukkan outlier yang signifikan.
# - Setelah proses cleaning dilakukan, dataset siap digunakan untuk analisis lebih lanjut.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Fixing Data Problems

# %%
# ubah tipe data kolom dteday menjadi datetime
day_df["dteday"] = pd.to_datetime(day_df["dteday"])
hour_df["dteday"] = pd.to_datetime(hour_df["dteday"])

# validasi ulang tipe data dan variabel kategorik
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
print("Validation After Cleaning:")
print("Season:", day_df["season"].unique())
print("Weather Situation:", day_df["weathersit"].unique())
print("Working Day:", day_df["workingday"].unique())
print("Holiday:", day_df["holiday"].unique())
# Out:
# Validation After Cleaning:
# Season: [1 2 3 4]
# Weather Situation: [2 1 3]
# Working Day: [0 1]
# Holiday: [0 1]

# %%
# Meninjau kembali outlier pada variabel numerik
plt.figure(figsize=(12,8))

plt.subplot(2,2,1)
sns.boxplot(x=day_df["cnt"])
plt.title("Total Bike Rentals (cnt)")

plt.subplot(2,2,2)
sns.boxplot(x=day_df["temp"])
plt.title("Temperature (temp)")

plt.subplot(2,2,3)
sns.boxplot(x=day_df["hum"])
plt.title("Humidity (hum)")

plt.subplot(2,2,4)
sns.boxplot(x=day_df["windspeed"])
plt.title("Windspeed")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:** (Opsional)
# - Kolom dteday berhasil dikonversi dari tipe object menjadi datetime64[ns], sehingga analisis berbasis waktu dapat dilakukan dengan lebih optimal.
# - Variabel kategorik seperti season, weathersit, workingday, dan holiday memiliki nilai yang valid dan konsisten dengan dokumentasi dataset.
# - Tidak ditemukan missing value maupun duplicate data sehingga tidak diperlukan proses penghapusan data.
# - Hasil pemeriksaan menunjukkan terdapat outlier pada variabel hum (humidity) dan windspeed, namun nilai tersebut masih dianggap sebagai kondisi yang wajar dalam data lingkungan dan cuaca, sehingga tidak dilakukan penghapusan data.
# - Variabel cnt dan temp tidak menunjukkan outlier yang signifikan.
# - Dataset telah bersih, konsisten, dan siap digunakan untuk tahap Exploratory Data Analysis (EDA).

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Data

# %%
# rata-rata jumlah penyewaan sepeda berdasarkan kondisi cuaca
weather_analysis = day_df.groupby("weathersit")["cnt"].agg(["mean", "max", "min"])
weather_analysis
# Out:
#                    mean   max  min
# weathersit
# 1           4876.786177  8714  431
# 2           4035.862348  8362  605
# 3           1803.285714  4639   22

# %%
# rata-rata jumlah penyewaan sepeda berdasarkan musim
season_analysis = day_df.groupby("season")["cnt"].agg(["mean", "max", "min"])
season_analysis
# Out:
#                mean   max   min
# season
# 1       2604.132597  7836   431
# 2       4992.331522  8362   795
# 3       5644.303191  8714  1115
# 4       4728.162921  8555    22

# %%
# perbandingan rata-rata penyewaan sepeda pada hari kerja dan bukan hari kerja
workingday_analysis = day_df.groupby("workingday")["cnt"].agg(["mean", "max", "min"])
workingday_analysis
# Out:
#                    mean   max  min
# workingday
# 0           4330.168831  8714  605
# 1           4584.820000  8362   22

# %% [markdown]
# **Insight:** (Opsional)
# - Cuaca memengaruhi jumlah penyewaan sepeda. Cuaca cerah (*weathersit* 1) memiliki rata-rata penyewaan tertinggi sebesar **4.876**, sedangkan cuaca buruk (*weathersit* 3) memiliki rata-rata terendah sebesar **1.803**. Semakin buruk cuaca, jumlah penyewaan semakin menurun.
# - Musim juga memengaruhi pola penyewaan. Musim gugur (*season* 3) memiliki rata-rata penyewaan tertinggi sebesar **5.644**, sedangkan musim semi (*season* 1) terendah sebesar **2.604**.
# - Hari kerja memiliki rata-rata penyewaan sedikit lebih tinggi (**4.584**) dibanding bukan hari kerja (**4.330**), menunjukkan sepeda banyak digunakan untuk aktivitas harian.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana pengaruh kondisi cuaca terhadap jumlah total penyewaan sepeda?

# %%
weather_labels = {
    1: "Clear Weather",
    2: "Misty",
    3: "Light Rain/Snow"
}

day_df["weather_label"] = day_df["weathersit"].map(weather_labels)

plt.figure(figsize=(8,5))
sns.barplot(x="weather_label", y="cnt", data=day_df)
plt.title("Average Bike Rentals by Weather Situation")
plt.xlabel("Weather Condition")
plt.ylabel("Average Total Rentals")
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Pada musim apa jumlah penyewaan sepeda tertinggi dan terendah terjadi?

# %%
season_labels = {
    1: "Spring",
    2: "Summer",
    3: "Fall",
    4: "Winter"
}

day_df["season_label"] = day_df["season"].map(season_labels)

plt.figure(figsize=(8,5))
sns.barplot(x="season_label", y="cnt", data=day_df)
plt.title("Average Bike Rentals by Season")
plt.xlabel("Season")
plt.ylabel("Average Total Rentals")
plt.show()

# %% [markdown]
# **Insight:** (Opsional)
# - Visualisasi menunjukkan bahwa kondisi cuaca cerah (weathersit 1) memiliki rata-rata penyewaan sepeda tertinggi, sedangkan cuaca buruk (weathersit 3) memiliki jumlah penyewaan terendah. Hal ini menunjukkan bahwa semakin buruk kondisi cuaca, semakin rendah jumlah penyewaan sepeda.
# - Berdasarkan musim, musim gugur (season 3) memiliki rata-rata penyewaan tertinggi, sedangkan musim semi (season 1) memiliki rata-rata terendah. Ini menunjukkan bahwa faktor musim berpengaruh terhadap tingkat penggunaan layanan bike sharing.
# - Hasil visualisasi memperkuat bahwa kondisi lingkungan seperti cuaca dan musim menjadi faktor penting dalam menentukan permintaan penyewaan sepeda.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ### Clustering Sederhana Berdasarkan Tingkat Permintaan

# %%
day_df["demand_category"] = pd.cut(
    day_df["cnt"],
    bins=3,
    labels=["Low Demand", "Medium Demand", "High Demand"]
)

day_df["demand_category"].value_counts()
# Out:
# demand_category
# Medium Demand    370
# High Demand      194
# Low Demand       167
# Name: count, dtype: int64

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# - **Conclusion pertanyaan 1:** Kondisi cuaca berpengaruh terhadap jumlah penyewaan sepeda. Cuaca cerah (weathersit 1) memiliki rata-rata penyewaan tertinggi, sedangkan cuaca buruk (weathersit 3) memiliki jumlah penyewaan terendah. Hal ini menunjukkan bahwa semakin buruk kondisi cuaca, semakin rendah jumlah penyewaan sepeda.
# - **Conclusion pertanyaan 2:** Musim memengaruhi pola penyewaan sepeda. Musim gugur (season 3) memiliki rata-rata penyewaan tertinggi, sedangkan musim semi (season 1) memiliki rata-rata terendah. Ini menunjukkan bahwa faktor musim berperan penting dalam menentukan tingkat penggunaan layanan bike sharing.
# - **Conclusion Analisis Lanjutan**: Hasil clustering menunjukkan bahwa sebagian besar hari berada pada kategori Medium Demand, diikuti High Demand dan Low Demand. Hal ini menunjukkan bahwa permintaan penyewaan sepeda paling sering berada pada tingkat sedang, namun perusahaan tetap perlu mengantisipasi lonjakan permintaan pada kondisi tertentu.

# %% [markdown]
# **Rekomendasi Action Item:**
# - Menambah jumlah armada sepeda pada musim dengan permintaan tinggi, terutama pada musim gugur dan saat kondisi cuaca cerah.
# - Memberikan promosi atau diskon pada saat cuaca buruk dan musim dengan permintaan rendah untuk menjaga jumlah penyewaan.
# - Mengoptimalkan perawatan armada pada hari dengan kategori Low Demand agar operasional tetap efisien.
# - Menggunakan hasil clustering permintaan harian untuk membantu perencanaan jumlah sepeda yang tersedia sesuai tingkat kebutuhan pengguna.

# %% [markdown]
# # Simpan Data

# %%
day_df.to_csv("main_data.csv", index=False)
